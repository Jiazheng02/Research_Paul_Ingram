# %%
import os
from PPTXProcessor import PPTXProcessor

# %%
id_path = "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/values for coding/combined id_ego thru fall 24.xlsx"
paths = [
    "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/all values/2023 G values.pptx"
]

# %%
for pptx_path in paths:

    extractor = PPTXProcessor(pptx_path, id_path)
    df = extractor.process_pptx_to_dataframe()
    
    # Remove file extension from pptx_path to avoid ".pptx.xlsx"
    output_filename = os.path.splitext(os.path.basename(pptx_path))[0] + "_extracted.xlsx"
    
    output_path = f"/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data Phase3/{output_filename}"
    
    df.to_excel(output_path, index=False, engine="openpyxl")
# Out:
# [2025/03/20 02:33:23] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/jiazhengtian/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/jiazhengtian/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320
# ...

# %%
for pptx_path in paths:

    extractor = PPTXProcessor(pptx_path, id_path)
    df = extractor.process_pptx_to_dataframe()
    
    # Remove file extension from pptx_path to avoid ".pptx.xlsx"
    output_filename = os.path.splitext(os.path.basename(pptx_path))[0] + "_extracted.xlsx"
    
    output_path = f"/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data Phase3/{output_filename}"
    
    df.to_excel(output_path, index=False, engine="openpyxl")
# Out:
# [2025/03/29 20:41:19] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/Users/jiazhengtian/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/Users/jiazhengtian/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320
# ...
