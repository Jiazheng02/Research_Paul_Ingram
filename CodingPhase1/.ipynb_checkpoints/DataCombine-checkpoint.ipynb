# %%
import pandas as pd

# %%
paths = [
    "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data/2024 A values_extracted_c.xlsx",
    "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data/2024 B values_extracted_c.xlsx",
    "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data/2024 E values_extracted_c.xlsx",
    "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data/2024 G values_extracted_c.xlsx",
    "/Users/jiazhengtian/Desktop/Research/Paul Ingram_25.2.21/Extracted Data/2024 M values_extracted_c.xlsx"
]

# %%
data_combine = []
for excel_path in paths:
    df = pd.read_excel(excel_path)
    data_combine.append(df)

data_combine = pd.concat(data_combine, ignore_index = True)
data_combine
# Out:
#        id_ego         Person Name                            From  \
# 0     10512.0  Bleecker Alexander  General Love Friend + Romantic
# 1     10512.0  Bleecker Alexander                           Humor
# 2     10512.0  Bleecker Alexander                 Intellectualism
# 3     10512.0  Bleecker Alexander               Make a Difference
# 4     10512.0  Bleecker Alexander                  Accomplishment
# ...       ...                 ...                             ...
# 2195  10138.0       Mark Thompson               Make a Difference
# 2196  10138.0       Mark Thompson                         Success
# 2197  10138.0       Mark Thompson                        Ambition
# 2198  10138.0       Mark Thompson                        Ambition
# 2199  10138.0       Mark Thompson                Responsibilities
#
#                                   To  NoMeaningfulEdges Operations    Data
# 0                           Serenity                  0        NaN  2024 A
# 1                           Serenity                  0        NaN  2024 A
# 2                              Humor                  0        NaN  2024 A
# 3     General Love Friend + Romantic                  0        NaN  2024 A
# 4                    Intellectualism                  0        NaN  2024 A
# ...                              ...                ...        ...     ...
# 2195                         Success                  0        NaN  2024 M
# 2196              Strong Work Ethics                  0        NaN  2024 M
# 2197                       Education                  0        NaN  2024 M
# 2198               Make a Difference                  0        NaN  2024 M
# 2199               Make a Difference                  0        NaN  2024 M
#
# [2200 rows x 7 columns]

# %%
# data_combine.to_excel("Combined_data.xlsx")
